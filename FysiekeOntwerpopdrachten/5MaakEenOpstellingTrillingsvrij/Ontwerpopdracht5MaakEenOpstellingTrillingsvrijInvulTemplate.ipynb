# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 53     |  |
# | :-------------|:-------------|
# | Parsa zandpour | 6579965 |
# | Joppe van Duin| 6405835 |
# | Sam Lindner| 6391214|

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep:53     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 11:40 | Joppe |
# | ontwerp-eis berekenen| 12:00 |Parsa en Sam|
# | activiteit 1 simulieren| 2:30 | hele groep |
# | activiteit 2 1e construtie opbouw| 3:30 | hele groep |
# | Mijlpaal 1 meten| 4:30 | ---|
# | Mijlpaal 2 inleveren| 5:30 | ---|
# | Pauze 1| 12:30-1:30 | hele groep |
# | Pauze 2| n/a | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 4/10 |
# | hoe lang voor één meting | 1s |
# | verwacht nauwkeurigheid meting | +/-0.1 m|

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie
omega = np.linspace(0, 100,int(1e6)) #omega array
omega_0= np.sqrt((10*np.pi)**2/4) #cut of angular freq
print('the cuttoff frequency is',int(omega_0*1000)/1000,'rad/s') 
A_ratio= 1/(1-(omega**2)/(omega_0**2)) #amplitude ratio
# Out:
# the cuttoff frequency is 15.707 rad/s

# %%
# Voeg hier je plot in.
plt.figure()
plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'r--') #ploting on a log-log scale
plt.xlabel('Log(Angular Frequency (Rad*s^-1))')
plt.ylabel('Log(Amplitude Ratio)')
plt.title('Angular Frequency vs the Amplitude Ratio on a Log-Log Plot')
plt.show()
# Out:
# /var/folders/9f/d_xndn2x1bx85yglm7bqd74c0000gn/T/ipykernel_36034/4028489578.py:3: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'r--') #ploting on a log-log scale

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
g=9.81
d_x=g/(omega_0**2)#delta x min
print(f'delta x minimum {d_x:.4f}m')
# Out:
# delta x minimum 0.0398m

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().
m = np.linspace(0.1,2,20)
c = (m*g)/d_x
"""c2 = (m*g)/(2*d_x)
c5 = (m*g)/(5*d_x)"""
plt.figure()
plt.plot(m,c,'r--', label='1*d_x') #normal d_x
plt.plot(m,c*2,'b--', label='2*d_x') #2x d_x
plt.plot(m,c*5,'k--', label='5*d_x') #5x d_x
plt.xlabel('Mass of Object (kg)')
plt.ylabel('Spring Constant (N/m)')
plt.legend()
plt.title('Mass vs Spring Constant')
plt.savefig('massa.png')
plt.show()

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - vul hier optie 1 in: smaller frequency
# - vul hier optie 2 in: smaller spring consant
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
#
#
# Als groep gaan we mikken op een $\Delta x$ van: 10cm omdat in onze simulaties afwijkt het design in het 6cm range and so we believe that sticking close to that as well as the dx min of 3cm to create as much damping as possible

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="IMG_4240.png" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
# Between 0.7cm and 0.9cm
#
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Ja
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **Voeg hier je antwoord in**
# 20 cm, dan raakt het de grond
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# **Voeg hier je antwoord in**
# Ja dat gaat lukken
#
# ### Gaat je ontwerp dus voldoen aan de eis?
# Ja
# **Voeg hier je antwoord in.**
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in.
d_x2= 0.08
omega_02= np.sqrt(g/d_x2) #cut of angular freq
A_ratio2= 1/(1-(omega**2)/(omega_02**2)) #amplitude ratio
print(f'Omega0 is {omega_02:.4f} Rad*s^-1')
plt.figure()
plt.plot(np.log(omega),np.log(np.abs(A_ratio2)),'r--', label='Proposed d_x') #ploting on a log-log scale
plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'b--',label='Ideal d_x') #ploting on a log-log scale
plt.xlabel('Log(Angular Frequency (Rad*s^-1))')
plt.ylabel('Log(Amplitude Ratio)')
plt.legend()
plt.title('Angular Frequency vs the Amplitude Ratio on a Log-Log Plot')
plt.show()
# Out:
# Omega0 is 11.0736 Rad*s^-1
# /var/folders/9f/d_xndn2x1bx85yglm7bqd74c0000gn/T/ipykernel_36034/2292809306.py:7: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(omega),np.log(np.abs(A_ratio2)),'r--', label='Proposed d_x') #ploting on a log-log scale
# /var/folders/9f/d_xndn2x1bx85yglm7bqd74c0000gn/T/ipykernel_36034/2292809306.py:8: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'b--',label='Ideal d_x') #ploting on a log-log scale

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plots in.

freq=np.array([2.5,4.4,8]) #measured freq
A_ratio_real= np.array([0.63/2.5,0.7/3.45,0.52/5.97]) #measured amp ratio

plt.figure()
plt.plot(np.log(2*np.pi*freq),np.log(np.abs(A_ratio_real)),'r.', label='Measured Values') #ploting on a log-log scale measured
plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'b--',label='Ideal d_x') #ploting on a log-log scale ideal
plt.xlabel('Log(Angular Frequency (Rad*s^-1))')
plt.ylabel('Log(Amplitude Ratio)')
plt.legend()
plt.title('Angular Frequency vs the Amplitude Ratio on a Log-Log Plot')
plt.show()
# Out:
# /var/folders/9f/d_xndn2x1bx85yglm7bqd74c0000gn/T/ipykernel_36034/1911407128.py:8: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'b--',label='Ideal d_x') #ploting on a log-log scale ideal

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# ## Leerdoel 1:
# Inzien dat de parameters in een differentiaalvergelijking ontwerpparameters zijn die een ontwerpruimte opspannen.

# %%
# Als je met Python je resultaten wil laten zien: voeg hier je code in.
print('leerdoel 1')
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
g=9.81
d_x=g/(omega_0**2)#delta x min
print(f'delta x minimum {d_x:.4f}m')

# Bereken hier je benodigde kantelfrequentie
omega = np.linspace(0, 100,int(1e6)) #omega array
omega_0= np.sqrt((10*np.pi)**2/4) #cut of angular freq
print('the cuttoff frequency is',int(omega_0*1000)/1000,'rad/s') 
A_ratio= 1/(1-(omega**2)/(omega_0**2)) #amplitude ratio
# Out:
# leerdoel 1
# delta x minimum 0.0398m
# the cuttoff frequency is 15.707 rad/s

# %% [markdown]
# ## Leerdoel 2:
# Op basis van een differentiaal vergelijking een keuze maken voor parameters en die vervolgens kunnen vertalen in een fysiek ontwerp.

# %%
# Voeg hier je plot in.
d_x2= 0.08
omega_02= np.sqrt(g/d_x2) #cut of angular freq
A_ratio2= 1/(1-(omega**2)/(omega_02**2)) #amplitude ratio
print(f'Omega0 is {omega_02:.4f} Rad*s^-1')
plt.figure()
plt.plot(np.log(omega),np.log(np.abs(A_ratio2)),'r--', label='Proposed d_x') #ploting on a log-log scale
plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'b--',label='Ideal d_x') #ploting on a log-log scale
plt.xlabel('Log(Angular Frequency (Rad*s^-1))')
plt.ylabel('Log(Amplitude Ratio)')
plt.legend()
plt.title('Angular Frequency vs the Amplitude Ratio on a Log-Log Plot')
plt.show()
freq=np.array([2.5,4.4,8]) #measured freq
A_ratio_real= np.array([0.63/2.5,0.7/3.45,0.52/5.97]) #measured amp ratio

plt.figure()
plt.plot(np.log(2*np.pi*freq),np.log(np.abs(A_ratio_real)),'r.', label='Measured Values') #ploting on a log-log scale measured
plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'b--',label='Ideal d_x') #ploting on a log-log scale ideal
plt.xlabel('Log(Angular Frequency (Rad*s^-1))')
plt.ylabel('Log(Amplitude Ratio)')
plt.legend()
plt.title('Angular Frequency vs the Amplitude Ratio on a Log-Log Plot')
plt.show()
# Out:
# Omega0 is 11.0736 Rad*s^-1
# /var/folders/9f/d_xndn2x1bx85yglm7bqd74c0000gn/T/ipykernel_36034/965499954.py:7: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(omega),np.log(np.abs(A_ratio2)),'r--', label='Proposed d_x') #ploting on a log-log scale
# /var/folders/9f/d_xndn2x1bx85yglm7bqd74c0000gn/T/ipykernel_36034/965499954.py:8: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'b--',label='Ideal d_x') #ploting on a log-log scale
# /var/folders/9f/d_xndn2x1bx85yglm7bqd74c0000gn/T/ipykernel_36034/965499954.py:19: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.log(omega),np.log(np.abs(A_ratio)),'b--',label='Ideal d_x') #ploting on a log-log scale ideal
